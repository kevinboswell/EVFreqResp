# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from FreqRespPy.data_search import get_target_file_list, open_target_file
from scipy import signal

# %%
def to_linear(x):
     return 10**(x / 10.0)

# %%
def to_dB(x):
    return 10 * np.log10(x)

# %%
def mean_freq_response(target_df):
    target_df = target_df.apply(pd.to_numeric)
    
    target_df_lin = to_linear(target_df)
    row_means_lin = target_df_lin.mean(axis=1)
    row_means_sem = target_df_lin.sem(axis=1)
  #  plt.subplot(2,1,1)
  #  plt.ylabel('Mean Sigma')
  #  plt.hist(row_means_lin)
  #  plt.subplot(2,1,2)
  #  plt.ylabel('Sigma SEM')
  #  plt.hist(row_means_sem)
  #  plt.show()
    row_means = to_dB(row_means_lin)
    return [row_means_lin, row_means_sem]

# %%
data_directory = '/Users/kevinb/Documents/GitHub/FreqResp/data/'
data_files = get_target_file_list(data_directory)
print(data_files)
# Out:
# ['FT_region_EV9_EVD_Comp0_Region 1.csv', 'FT_region_EV9_EVD_Comp0_Region 2.csv', 'FT_region_EV9_EVD_Comp0_Region 45.csv', 'FT_region_EV9_EVD_Comp0_Region 46.csv', 'FT_region_EV9_EVD_Comp1_Region 1.csv', 'FT_region_EV9_EVD_Comp1_Region 2.csv', 'FT_region_EV9_EVD_Comp1_Region 45.csv', 'FT_region_EV9_EVD_Comp1_Region 46.csv', 'FT_region_RAW_EV9_Region 1.csv', 'FT_region_RAW_EV9_Region 2.csv', 'FT_region_RAW_EV9_Region 45.csv', 'FT_region_RAW_EV9_Region 46.csv']

# %%
mean_response_output = []
mean_sem_output = []

for file in data_files:
    meta, df = open_target_file(data_directory, file)
    #   print(df)
    #   print(df.dtypes)
    
    mean_response, mean_sem = mean_freq_response(df)
    mean_response_output.append(mean_response)
    mean_sem_output.append(mean_sem)

# %%
#mean_response_output

# %%
df_output_mean = pd.concat(mean_response_output, axis=1)
df_output_sem = pd.concat(mean_sem_output, axis=1)

# %%
type(df_output_mean)
df_output_mean.shape
df_output_mean.columns.values
df_output_mean.columns = [file.replace(' ', '_') for file in data_files]

df_output_sem.shape
df_output_sem.columns.values
df_output_sem.columns = [file.replace(' ', '_') for file in data_files]

# %%
data_files = [file.replace(' ', '_') for file in data_files]
data_files = [file[:-4] for file in data_files if file.endswith('.csv')]
data_files = [file[10:] for file in data_files if file.startswith('FT_region_')]

# %%
df_output_mean.columns = data_files
df_output_mean.columns
print(type(df_output_mean))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_output_sem.columns = data_files
df_output_sem.columns
# Out:
# Index(['EV9_EVD_Comp0_Region_1', 'EV9_EVD_Comp0_Region_2',
#        'EV9_EVD_Comp0_Region_45', 'EV9_EVD_Comp0_Region_46',
#        'EV9_EVD_Comp1_Region_1', 'EV9_EVD_Comp1_Region_2',
#        'EV9_EVD_Comp1_Region_45', 'EV9_EVD_Comp1_Region_46',
#        'RAW_EV9_Region_1', 'RAW_EV9_Region_2', 'RAW_EV9_Region_45',
#        'RAW_EV9_Region_46'],
#       dtype='object')

# %%
target1_mean = 10*np.log10(df_output_mean.iloc[:,0])   # Fish1
target1_low_sem = 10*np.log10(df_output_mean.iloc[:,0] - df_output_sem.iloc[:,0])   
target1_upp_sem = 10*np.log10(df_output_mean.iloc[:,0] + df_output_sem.iloc[:,0])  

target2_mean = 10*np.log10(df_output_mean.iloc[:,3])   # Fish1 
target2_low_sem = 10*np.log10(df_output_mean.iloc[:,3] - df_output_sem.iloc[:,3])  
target2_upp_sem = 10*np.log10(df_output_mean.iloc[:,3] + df_output_sem.iloc[:,3])  

target3_mean= 10*np.log10(df_output_mean.iloc[:,2])   # Fish2
target3_low_sem= 10*np.log10(df_output_mean.iloc[:,2] - df_output_sem.iloc[:,2])   
target3_upp_sem= 10*np.log10(df_output_mean.iloc[:,2] + df_output_sem.iloc[:,2])  

target4_mean= 10*np.log10(df_output_mean.iloc[:,10])   # Fish2
target4_low_sem= 10*np.log10(df_output_mean.iloc[:,10] - df_output_sem.iloc[:,10]) 
target4_upp_sem= 10*np.log10(df_output_mean.iloc[:,10] + df_output_sem.iloc[:,10])

freq=df.index

# %%
plt.xlabel('Frequency [kHz]')
plt.ylabel('Target Strength [dB]')

plt.plot(freq,target1_mean, '-', color='green', zorder=1)
plt.fill_between(freq, target1_low_sem, target1_upp_sem,
                 color='gray', alpha=0.2)


plt.plot(freq,target2_mean, '-', color='orange', zorder=2)
plt.fill_between(freq, target2_low_sem, target2_upp_sem,
                 color='gray', alpha=0.2)

plt.plot(freq,target3_mean, '-', color='red', zorder=3)
plt.fill_between(freq, target3_low_sem, target3_upp_sem,
                 color='gray', alpha=0.2)


plt.plot(freq,target4_mean, '-', color='blue', zorder=4)
plt.fill_between(freq, target4_low_sem, target4_upp_sem,
                 color='gray', alpha=0.2)

# %%
## need to integrate file names into this to loop across fish tracks
i = 0
while i < len(data_files):
    plt.rcParams["font.size"] = 12
    plt.plot(freq, (10*np.log10(df_output_mean.iloc[:,i])),zorder=len(data_files)-i) 
#    plt.plot (freq, (10*np.log10(df_output_mean.iloc[:,i] - df_output_sem.iloc[:,i])))
    plt.fill_between(freq, 10*np.log10(df_output_mean.iloc[:,i] - df_output_sem.iloc[:,i]),
                     10*np.log10(df_output_mean.iloc[:,i] + df_output_sem.iloc[:,i]),
                     color='gray', alpha=0.2)          
    plt.xlabel('Frequency [kHz]')
    plt.ylabel('Target Strength [dB]')
#   print (i)
    i = i + 1

# %%
df_output_sem.columns
# Out:
# Index(['EV9_EVD_Comp0_Region_1', 'EV9_EVD_Comp0_Region_2',
#        'EV9_EVD_Comp0_Region_45', 'EV9_EVD_Comp0_Region_46',
#        'EV9_EVD_Comp1_Region_1', 'EV9_EVD_Comp1_Region_2',
#        'EV9_EVD_Comp1_Region_45', 'EV9_EVD_Comp1_Region_46',
#        'RAW_EV9_Region_1', 'RAW_EV9_Region_2', 'RAW_EV9_Region_45',
#        'RAW_EV9_Region_46'],
#       dtype='object')

# %%
a=10*np.log10(df_output_mean.iloc[:,0])   #EV9_EVD_Comp0_Region_1
b=10*np.log10(df_output_mean.iloc[:,1])   #EV9_EVD_Comp0_Region_2
c=10*np.log10(df_output_mean.iloc[:,2])   #EV9_EVD_Comp0_Region_45
d=10*np.log10(df_output_mean.iloc[:,3])   #EV9_EVD_Comp0_Region_46
e=10*np.log10(df_output_mean.iloc[:,4])   #EV9_EVD_Comp1_Region_1
f=10*np.log10(df_output_mean.iloc[:,5])   #EV9_EVD_Comp1_Region_2
g=10*np.log10(df_output_mean.iloc[:,6])   #EV9_EVD_Comp1_Region_45
h=10*np.log10(df_output_mean.iloc[:,7])   #EV9_EVD_Comp1_Region_46
i=10*np.log10(df_output_mean.iloc[:,8])   # RAW_EV9_Region_1
j=10*np.log10(df_output_mean.iloc[:,9])   # RAW_EV9_Region_2
k=10*np.log10(df_output_mean.iloc[:,10])  # RAW_EV9_Region_45
l=10*np.log10(df_output_mean.iloc[:,11])  # RAW_EV9_Region_46

# No diffs b/w Comp0 and Comp1 
x1= a-e     #EV9_EVD_Comp0_Region_1 - EV9_EVD_Comp1_Region_1
x2= b-f     #EV9_EVD_Comp0_Region_2 - EV9_EVD_Comp1_Region_2
x3= c-g     #EV9_EVD_Comp0_Region_45 - EV9_EVD_Comp1_Region_45
x4= d-h     #EV9_EVD_Comp0_Region_46- EV9_EVD_Comp1_Region_46
x5= a-i     #EV9_EVD_Comp0_Region_1 - RAW_EV9_Region_1
x6= e-i     #EV9_EVD_Comp1_Region_1 - RAW_EV9_Region_1
x7= b-j     #EV9_EVD_Comp0_Region_2 -  RAW_EV9_Region_2
x8= f-j     #EV9_EVD_Comp1_Region_2 - RAW_EV9_Region_2

# Raw 
# x9 -  x10 vary by same amount
x9= c-k   #EV9_EVD_Comp0_Region_45 - RAW_EV9_Region_45
x10= g-k   #EV9_EVD_Comp1_Region_45 - RAW_EV9_Region_45

# x11-x12 vary by much more and in the other direction as above
x11= d-l   #EV9_EVD_Comp0_Region_46 - RAW_EV9_Region_46
x12= h-l  #EV9_EVD_Comp1_Region_46 - RAW_EV9_Region_46

out=[x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12]
outz=pd.DataFrame(out)

m = 0
while m < len(outz):
   plt.rcParams["font.size"] = 12
   plt.plot(freq, outz.iloc[m,:]) 
   plt.xlabel('Frequency [kHz]')
   plt.ylabel('Target Strength [dB]')
   m = m + 1
